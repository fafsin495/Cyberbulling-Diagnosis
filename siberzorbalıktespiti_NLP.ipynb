# %% [markdown]
# # İçindekiler
# 1. [Veri Setinin Yüklenmesi](#1)
# 2. [Veri Ön İşleme](#2)
# 3. [Veri Setinin Görselleştirilmesi](#3)
# 4. [Modelin Test ve Eğitim Kümelerine Ayrılması](#4)
# 5. [Sınıflandırma Algoritmalarının Denenmesi](#5)
# 6. [Sonuç](#6)

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/siber-zorbalk/deneme.csv
# /kaggle/input/siber-zorbalk/tweetset.csv
# /kaggle/input/siber-zorbalk/newcsv.csv

# %% [markdown]
# <a id= "1"> </a><br>
# ## Veri Setini Yüklüyoruz

# %%
df = pd.read_csv("/kaggle/input/siber-zorbalk/tweetset.csv",encoding="windows-1254")
df.head()
# Out:
#        Tip                                           Paylaşım Unnamed: 2  \
# 0  Negatif                      Doğa ağzımıza sıçsa hakkı var        NaN
# 1  Pozitif  Anne bir sanatçıdır, en güzel eseri de yavrusu...        NaN
# 2  Negatif   ibrahimin oğlunu koruyan Tanrı’ya da ben sokayım        NaN
# 3  Negatif        Köpeğim suratına sıçsın senin namussuz karı        NaN
# 4  Negatif                Ben söğüşledim, birazda sen söğüşle        NaN
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5
# 0         NaN        NaN        NaN
# 1         NaN        NaN        NaN
# 2         NaN        NaN        NaN
# 3         NaN        NaN        NaN
# 4         NaN        NaN        NaN

# %% [markdown]
# Veri setinin içerisindeki özniteliklere bakacak olursak "Tip" ve "Paylaşım" olmak üzere 2 öznitelik vardır.
#
# Bu özniteliklerin haricinde "NaN" yani boş değerlerle dolu olan öznitelikleri silmemiz gerekiyor .
#
# **Paylaşım :** Sosyal medya platformu olan Tweetter'da kullanıcıların yaptıkları paylaşımların içeriklerini göstermektedir.
#
# **Tip :** Atılan tweet lerin siber zorbalık ifade edip etmediğinin etiketlendiği öz niteliktir. "Pozitif","Negatif"

# %% [markdown]
# <a id= "2"> </a><br>
# # Veri Ön İşleme

# %%
# Veri setinde kayıp verilerin olup olmadığına bakıyoruz ve düzeltilemeyecek kadar olan feature'leri siliyoruz
print("Kayıp Veriler :{}".format(df.isnull().sum()))
# Out:
# Kayıp Veriler :Tip               0
# Paylaşım          0
# Unnamed: 2    11109
# Unnamed: 3    11111
# Unnamed: 4    11110
# Unnamed: 5    11110
# dtype: int64

# %%
df.drop(["Unnamed: 2","Unnamed: 3","Unnamed: 4","Unnamed: 5"],axis=1,inplace=True)

# %%
#Label encoder işlemi yaparak veri seti içerisinde bulunan "Negatif" değerli 0 "Pozitif" değerleri ise 1 yapıyoruz.
df["sınıf"] = [0 if (i=="Negatif") else 1 for i in df["Tip"]]
df.head()
# Out:
#        Tip                                           Paylaşım  sınıf
# 0  Negatif                      Doğa ağzımıza sıçsa hakkı var      0
# 1  Pozitif  Anne bir sanatçıdır, en güzel eseri de yavrusu...      1
# 2  Negatif   ibrahimin oğlunu koruyan Tanrı’ya da ben sokayım      0
# 3  Negatif        Köpeğim suratına sıçsın senin namussuz karı      0
# 4  Negatif                Ben söğüşledim, birazda sen söğüşle      0

# %%
import string
from nltk.corpus import stopwords
from collections import Counter
from nltk.stem.porter import PorterStemmer
import re
from nltk.stem import WordNetLemmatizer

# %%
punctation = string.punctuation
#punctuation ='''!()-[]{};':'"\,<>./?@#$%^&*_~'''
#Özel karakterleri temizleme
def ozelkarakter_temizleme (metin):
    return metin.translate(str.maketrans("","",punctation))

#--------------------
#Stopword temizleme

#stopword = set(stopwords.words("turkish"))
stopword = "acaba, ama, ancak, artık, asla, aslında, az,bana, bazen, bazı, bazıları, bazısı, belki, ben, beni, benim, beş, bile, bir, birçoğu, birçok, birçokları, biri, birisi, birkaç, birkaçı, birşey, birşeyi, biz, bize, bizi, bizim, böyle, böylece, bu, buna, bunda, bundan, bunu, bunun, burada, bütün,çoğu, çoğuna, çoğunu, çok, çünkü,da, daha, de, değil, demek, diğer, diğeri, diğerleri, diye, dolayı,elbette, en,fakat, falan, felan, filan, gene, gibi,hangi, hangisi, hani, hatta, hem, henüz, hep, hepsi, hepsine, hepsini, her, her biri, herkes, herkese, herkesi, hiç, hiç kimse, hiçbiri, hiçbirine, hiçbirini,için, içinde, ile, ise, işte,kaç, kadar, kendi, kendine, kendini, ki, kim, kime, kimi, kimin, kimisi,madem, mı, mi, mu, mü,nasıl, ne, ne kadar, ne zaman, neden, nedir, nerde, nerede, nereden, nereye, nesi, neyse, niçin, niye,ona, ondan, onlar, onlara, onlardan, onların, onu, onun, orada, oysa, oysaki,öbürü, ön, önce, ötürü, öyle, sana, sen, senden, seni, senin, siz, sizden, size, sizi, sizin, son, sonra, seobilog,şayet, şey, şimdi, şöyle, şu, şuna, şunda, şundan, şunlar, şunu, şunun,tabi, tamam, tüm, tümü, üzere,var, ve, veya, veyahut,ya, ya da, yani, yerine, yine, yoksa,zaten, zira"

def stopwords_temizleme (metin):
    return " ".join([kelime for kelime in str(metin).split() if kelime not in stopword])

#-------------------
count = Counter()

#sık kullanılan kelimeleri temizleme
for metin in df["Paylaşım"].values:
    for kelime in metin.split():
        count[kelime] += 1
count.most_common(10) # en sık tekrar eden 10 kelimeyi gösterir
frekans = set([i for (i,j) in count.most_common(15)])
nadir = 15
nadir_kelime = set([i for (i,j) in count.most_common()[:-nadir-1:-1]])
def frekans_sil(metin):
    return " ".join([kelime for kelime in str(metin).split() if kelime not in frekans])


#----------------Kelime Kökünü Alma
lemma = WordNetLemmatizer()
#Lemmatizer

def kelime_kök_alma (metin):
    return " ".join([lemma.lemmatize(kelime) for kelime in metin.split()])
 
    
    
    
#---------
#Emojileri Silme

def emoji_silme (metin):
    emoji = re.compile("["
                               u"\U0001F600-\U0001F64F"  
                               u"\U0001F300-\U0001F5FF"                                 u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  
                               u"\U00002500-\U00002BEF"                                 u"\U00002702-\U000027B0"
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               u"\U0001f926-\U0001f937"
                               u"\U00010000-\U0010ffff"
                               u"\u2640-\u2642"
                               u"\u2600-\u2B55"
                               u"\u200d"
                               u"\u23cf"
                               u"\u23e9"
                               u"\u231a"
                               u"\ufe0f"  
                               u"\u3030"
                               "]+", flags=re.UNICODE)
    return emoji.sub(r"",metin)

# %%
df["Paylaşım"] = df["Paylaşım"].str.lower()
df["ozel_karaktersiz"] = df["Paylaşım"].apply(lambda metin : ozelkarakter_temizleme(metin))
df["stop_word"] = df["ozel_karaktersiz"].apply(lambda metin : stopwords_temizleme(metin) )
df["sık_kullanılan"] = df["stop_word"].apply(lambda metin : frekans_sil(metin) )
df["kelime_kok"] = df["sık_kullanılan"].apply(lambda kelime : kelime_kök_alma(kelime))
df["emojisiz"] = df["kelime_kok"].apply(lambda metin : emoji_silme(metin))
df.head(50)
# Out:
#         Tip                                           Paylaşım  sınıf  \
# 0   Negatif                      doğa ağzımıza sıçsa hakkı var      0
# 1   Pozitif  anne bir sanatçıdır, en güzel eseri de yavrusu...      1
# 2   Negatif   ibrahimin oğlunu koruyan tanrı’ya da ben sokayım      0
# 3   Negatif        köpeğim suratına sıçsın senin namussuz karı      0
# 4   Negatif                ben söğüşledim, birazda sen söğüşle      0
# 5   Negatif  şerefsizlik, sözde sanatçıların vazgeçemediği ...      0
# 6   Negatif              kendisi de bilmiyordur çünkü beyinsiz      0
# 7   Negatif  aşırı bıyıklı geleneksel keko adam, bi ayrılıp...      0
# 8   Pozitif  en uzun yolculuklar bile, tek bir adımla başla...      1
# 9   Pozitif        vallahi bu aralar istediğimiz tek şey huzur      1
# 10  Pozitif  chp genel başkanı kemal kılıçdaroğlu'nun eşi s...      1
# 11  Pozitif  beyin göçünü engellemeye çalıştığımız gençlere...      1
# 12  Pozitif        doğa ana bu kullanılmayan depoyu devralıyor      1
# 13  Pozitif  tarlasını çekerken beni niye çekmedin diye söy...      1
# 14  Negatif  babaannesini seven yoktur heralde anneanneler ...      0
# 15  Pozitif  merhaba, konuyla ilgili yardımcı olmak isteriz...      1
# 16  Pozitif  nietzsche böyle buyurdu zerdüşt’te; "ama önce ...      1
# 17  Pozitif  hiçbir şey harekete geçen cehalet kadar korkun...      1
# 18  Pozitif  yine birileri bazı değişimlerin tadını çıkarma...      1
# 19  Pozitif  "stanley parable diye bir oyun var abi sevebil...      1
# 20  Pozitif  "seni kitap okuyan insanlarla tanıştıracağım. ...      1
# 21  Pozitif              yaptığım en başarılı aktivite uyumak.      1
# 22  Negatif  kim demiş iyilerle kötüler belli değil diye;it...      0
# 23  Negatif  hiç bir faydası olmayan, zararı olan, saray so...      0
# 24  Negatif  ulan yanan alevi yakan alevi bugün temel ile a...      0
# 25  Negatif  defol git lan, ölüye saygın yok anladık bari a...      0
# 26  Pozitif  2018'den bu yana formamızı terleten, sadece ba...      1
# 27  Negatif  kanka ben netflix sayesinde ingilizce ogreniyo...      0
# 28  Negatif                                         öldürür bu      0
# 29  Pozitif  o zaman para vermeyeceksin kardeşim. he demek ...      1
# 30  Negatif                                gay düsmani mustafa      0
# 31  Pozitif  neden? i̇zlemek istemeyen abone olmaz. açık sa...      1
# 32  Negatif                             izleme o zaman dalyrak      0
# 33  Negatif  türk televizyon dizileri: tecavüz, kadına şidd...      0
# 34  Negatif               i̇zleme be amına kodumun koyunu seni      0
# 35  Negatif                   fiyatı mı fazla geldi gerizekalı      0
# 36  Negatif  ezik orospu evladi izleyen ister ucretli bir u...      0
# 37  Negatif  i̇zleme ozaman yarram bi karı görsen düz yokuş...      0
# 38  Negatif  zehirin aktığı yer sizin beyniniz ve ağzınız a...      0
# 39  Negatif  hayatında hiç para vermeden seks yapmamış, çev...      0
# 40  Negatif  aq ayık gezmezler her bulduğunu skerler abazal...      0
# 41  Negatif  sus lan yavşak   izleme götüm zaten siz fakirl...      0
# 42  Negatif                                  satın almayın amk      0
# 43  Pozitif  bir dur da dinle ademoğlu nasıl geldin nasıl g...      1
# 44  Pozitif  hepsinin ötesinde, bu baskıcı dönemde alınan t...      1
# 45  Negatif  motorsikletin yanından geçen motorcu oluyor am...      0
# 46  Pozitif  benim bir korkum yok konuyu çarpıtmayada gerek...      1
# 47  Pozitif  başkalarına yapılan hukuk dışı, ahlak dışı ola...      1
# 48  Pozitif  doğduğum günden tam 22 yıl sonra yine aynı tar...      1
# 49  Pozitif  çok komiksin ya, burun deliklerini kapat güler...      1
#
#                                      ozel_karaktersiz  \
# 0                       doğa ağzımıza sıçsa hakkı var
# 1   anne bir sanatçıdır en güzel eseri de yavrusudur
# 2    ibrahimin oğlunu koruyan tanrı’ya da ben sokayım
# 3         köpeğim suratına sıçsın senin namussuz karı
# 4                  ben söğüşledim birazda sen söğüşle
# 5   şerefsizlik sözde sanatçıların vazgeçemediği b...
# 6               kendisi de bilmiyordur çünkü beyinsiz
# 7   aşırı bıyıklı geleneksel keko adam bi ayrılıp ...
# 8   en uzun yolculuklar bile tek bir adımla başlar...
# 9         vallahi bu aralar istediğimiz tek şey huzur
# 10  chp genel başkanı kemal kılıçdaroğlunun eşi se...
# 11  beyin göçünü engellemeye çalıştığımız gençlere...
# 12        doğa ana bu kullanılmayan depoyu devralıyor
# 13  tarlasını çekerken beni niye çekmedin diye söy...
# 14  babaannesini seven yoktur heralde anneanneler ...
# 15  merhaba konuyla ilgili yardımcı olmak isteriz ...
# 16  nietzsche böyle buyurdu zerdüşt’te ama önce se...
# 17  hiçbir şey harekete geçen cehalet kadar korkun...
# 18  yine birileri bazı değişimlerin tadını çıkarma...
# 19  stanley parable diye bir oyun var abi sevebili...
# 20  seni kitap okuyan insanlarla tanıştıracağım ha...
# 21               yaptığım en başarılı aktivite uyumak
# 22  kim demiş iyilerle kötüler belli değil diyeit ...
# 23  hiç bir faydası olmayan zararı olan saray soyt...
# 24  ulan yanan alevi yakan alevi bugün temel ile a...
# 25  defol git lan ölüye saygın yok anladık bari al...
# 26  2018den bu yana formamızı terleten sadece başa...
# 27  kanka ben netflix sayesinde ingilizce ogreniyo...
# 28                                         öldürür bu
# 29  o zaman para vermeyeceksin kardeşim he demek p...
# 30                                gay düsmani mustafa
# 31  neden i̇zlemek istemeyen abone olmaz açık sahn...
# 32                             izleme o zaman dalyrak
# 33  türk televizyon dizileri tecavüz kadına şiddet...
# 34               i̇zleme be amına kodumun koyunu seni
# 35                   fiyatı mı fazla geldi gerizekalı
# 36  ezik orospu evladi izleyen ister ucretli bir u...
# 37  i̇zleme ozaman yarram bi karı görsen düz yokuş...
# 38  zehirin aktığı yer sizin beyniniz ve ağzınız a...
# 39  hayatında hiç para vermeden seks yapmamış çevr...
# 40  aq ayık gezmezler her bulduğunu skerler abazal...
# 41  sus lan yavşak   izleme götüm zaten siz fakirl...
# 42                                  satın almayın amk
# 43  bir dur da dinle ademoğlu nasıl geldin nasıl g...
# 44  hepsinin ötesinde bu baskıcı dönemde alınan tü...
# 45  motorsikletin yanından geçen motorcu oluyor am...
# 46  benim bir korkum yok konuyu çarpıtmayada gerek...
# 47  başkalarına yapılan hukuk dışı ahlak dışı olay...
# 48  doğduğum günden tam 22 yıl sonra yine aynı tar...
# 49  çok komiksin ya burun deliklerini kapat gülerk...
#
#                                             stop_word  \
# 0                           doğa ağzımıza sıçsa hakkı
# 1              anne sanatçıdır güzel eseri yavrusudur
# 2           ibrahimin oğlunu koruyan tanrı’ya sokayım
# 3               köpeğim suratına sıçsın namussuz karı
# 4                          söğüşledim birazda söğüşle
# 5   şerefsizlik sözde sanatçıların vazgeçemediği d...
# 6                        kendisi bilmiyordur beyinsiz
# 7   aşırı bıyıklı geleneksel keko adam ayrılıp bar...
# 8   uzun yolculuklar tek adımla başlar geleceğin m...
# 9                vallahi aralar istediğimiz tek huzur
# 10  chp genel başkanı kemal kılıçdaroğlunun eşi se...
# 11  beyin göçünü engellemeye çalıştığımız gençlere...
# 12               doğa kullanılmayan depoyu devralıyor
# 13  tarlasını çekerken çekmedin söylenenen dayının...
# 14  babaannesini seven yoktur heralde anneanneler ...
# 15  merhaba konuyla ilgili yardımcı olmak isteriz ...
# 16  nietzsche buyurdu zerdüşt’te inşa etmelisin di...
# 17              harekete geçen cehalet korkunç olamaz
# 18     birileri değişimlerin tadını çıkarmakla meşgul
# 19  stanley parable oyun sevebilirsin cümlesini un...
# 20  kitap okuyan insanlarla tanıştıracağım hayat i...
# 21                  yaptığım başarılı aktivite uyumak
# 22  demiş iyilerle kötüler belli diyeit itle gezer...
# 23  faydası olmayan zararı olan saray soytarısı na...
# 24  ulan yanan alevi yakan alevi bugün temel aynı ...
# 25  defol git ölüye saygın anladık bari allahtan k...
# 26  2018den yana formamızı terleten sadece başarıl...
# 27  kanka netflix sayesinde ingilizce ogreniyorum ...
# 28                                            öldürür
# 29  para vermeyeceksin kardeşim para verdin izleme...
# 30                                gay düsmani mustafa
# 31  i̇zlemek istemeyen abone olmaz açık sahneyse e...
# 32                                     izleme dalyrak
# 33  türk televizyon dizileri tecavüz kadına şiddet...
# 34                       i̇zleme amına kodumun koyunu
# 35                      fiyatı fazla geldi gerizekalı
# 36  ezik orospu evladi izleyen ister ucretli uygulama
# 37  i̇zleme ozaman yarram karı görsen düz yokuşa t...
# 38  zehirin aktığı beyniniz ağzınız farkında değil...
# 39  hayatında para vermeden seks yapmamış çevresi ...
# 40  aq ayık gezmezler bulduğunu skerler abazalıkta...
# 41  sus yavşak izleme götüm fakirlerin netfilixi o...
# 42                                  satın almayın amk
# 43               dur dinle ademoğlu geldin gidiyorsun
# 44  hepsinin ötesinde baskıcı dönemde alınan karar...
# 45  motorsikletin yanından geçen motorcu oluyor am...
# 46  korkum konuyu çarpıtmayada gerek olursa olsun ...
# 47  başkalarına yapılan hukuk dışı ahlak dışı olay...
# 48  doğduğum günden 22 yıl aynı tarihte mezun oldu...
# 49   komiksin burun deliklerini kapat gülerken corona
#
#                                        sık_kullanılan  \
# 0                           doğa ağzımıza sıçsa hakkı
# 1              anne sanatçıdır güzel eseri yavrusudur
# 2           ibrahimin oğlunu koruyan tanrı’ya sokayım
# 3               köpeğim suratına sıçsın namussuz karı
# 4                          söğüşledim birazda söğüşle
# 5   şerefsizlik sözde sanatçıların vazgeçemediği d...
# 6                        kendisi bilmiyordur beyinsiz
# 7   aşırı bıyıklı geleneksel keko adam ayrılıp bar...
# 8   uzun yolculuklar tek adımla başlar geleceğin m...
# 9                vallahi aralar istediğimiz tek huzur
# 10  chp genel başkanı kemal kılıçdaroğlunun eşi se...
# 11  beyin göçünü engellemeye çalıştığımız gençlere...
# 12               doğa kullanılmayan depoyu devralıyor
# 13  tarlasını çekerken çekmedin söylenenen dayının...
# 14  babaannesini seven yoktur heralde anneanneler ...
# 15  merhaba konuyla ilgili yardımcı olmak isteriz ...
# 16  nietzsche buyurdu zerdüşt’te inşa etmelisin di...
# 17              harekete geçen cehalet korkunç olamaz
# 18     birileri değişimlerin tadını çıkarmakla meşgul
# 19  stanley parable oyun sevebilirsin cümlesini un...
# 20  kitap okuyan insanlarla tanıştıracağım hayat i...
# 21                  yaptığım başarılı aktivite uyumak
# 22  demiş iyilerle kötüler belli diyeit itle gezer...
# 23  faydası olmayan zararı olan saray soytarısı na...
# 24  ulan yanan alevi yakan alevi bugün temel aynı ...
# 25  defol git ölüye saygın anladık bari allahtan k...
# 26  2018den yana formamızı terleten sadece başarıl...
# 27  kanka netflix sayesinde ingilizce ogreniyorum ...
# 28                                            öldürür
# 29  para vermeyeceksin kardeşim para verdin izleme...
# 30                                gay düsmani mustafa
# 31  i̇zlemek istemeyen abone olmaz açık sahneyse e...
# 32                                     izleme dalyrak
# 33  türk televizyon dizileri tecavüz kadına şiddet...
# 34                       i̇zleme amına kodumun koyunu
# 35                      fiyatı fazla geldi gerizekalı
# 36  ezik orospu evladi izleyen ister ucretli uygulama
# 37  i̇zleme ozaman yarram karı görsen düz yokuşa t...
# 38  zehirin aktığı beyniniz ağzınız farkında değil...
# 39  hayatında para vermeden seks yapmamış çevresi ...
# 40  aq ayık gezmezler bulduğunu skerler abazalıkta...
# 41  sus yavşak izleme götüm fakirlerin netfilixi o...
# 42                                  satın almayın amk
# 43               dur dinle ademoğlu geldin gidiyorsun
# 44  hepsinin ötesinde baskıcı dönemde alınan karar...
# 45  motorsikletin yanından geçen motorcu oluyor am...
# 46  korkum konuyu çarpıtmayada gerek olursa olsun ...
# 47  başkalarına yapılan hukuk dışı ahlak dışı olay...
# 48  doğduğum günden 22 yıl aynı tarihte mezun oldu...
# 49   komiksin burun deliklerini kapat gülerken corona
#
#                                            kelime_kok  \
# 0                           doğa ağzımıza sıçsa hakkı
# 1              anne sanatçıdır güzel eseri yavrusudur
# 2           ibrahimin oğlunu koruyan tanrı’ya sokayım
# 3               köpeğim suratına sıçsın namussuz karı
# 4                          söğüşledim birazda söğüşle
# 5   şerefsizlik sözde sanatçıların vazgeçemediği d...
# 6                        kendisi bilmiyordur beyinsiz
# 7   aşırı bıyıklı geleneksel keko adam ayrılıp bar...
# 8   uzun yolculuklar tek adımla başlar geleceğin m...
# 9                vallahi aralar istediğimiz tek huzur
# 10  chp genel başkanı kemal kılıçdaroğlunun eşi se...
# 11  beyin göçünü engellemeye çalıştığımız gençlere...
# 12               doğa kullanılmayan depoyu devralıyor
# 13  tarlasını çekerken çekmedin söylenenen dayının...
# 14  babaannesini seven yoktur heralde anneanneler ...
# 15  merhaba konuyla ilgili yardımcı olmak isteriz ...
# 16  nietzsche buyurdu zerdüşt’te inşa etmelisin di...
# 17              harekete geçen cehalet korkunç olamaz
# 18     birileri değişimlerin tadını çıkarmakla meşgul
# 19  stanley parable oyun sevebilirsin cümlesini un...
# 20  kitap okuyan insanlarla tanıştıracağım hayat i...
# 21                  yaptığım başarılı aktivite uyumak
# 22  demiş iyilerle kötüler belli diyeit itle gezer...
# 23  faydası olmayan zararı olan saray soytarısı na...
# 24  ulan yanan alevi yakan alevi bugün temel aynı ...
# 25  defol git ölüye saygın anladık bari allahtan k...
# 26  2018den yana formamızı terleten sadece başarıl...
# 27  kanka netflix sayesinde ingilizce ogreniyorum ...
# 28                                            öldürür
# 29  para vermeyeceksin kardeşim para verdin izleme...
# 30                                gay düsmani mustafa
# 31  i̇zlemek istemeyen abone olmaz açık sahneyse e...
# 32                                     izleme dalyrak
# 33  türk televizyon dizileri tecavüz kadına şiddet...
# 34                       i̇zleme amına kodumun koyunu
# 35                      fiyatı fazla geldi gerizekalı
# 36  ezik orospu evladi izleyen ister ucretli uygulama
# 37  i̇zleme ozaman yarram karı görsen düz yokuşa t...
# 38  zehirin aktığı beyniniz ağzınız farkında değil...
# 39  hayatında para vermeden seks yapmamış çevresi ...
# 40  aq ayık gezmezler bulduğunu skerler abazalıkta...
# 41  sus yavşak izleme götüm fakirlerin netfilixi o...
# 42                                  satın almayın amk
# 43               dur dinle ademoğlu geldin gidiyorsun
# 44  hepsinin ötesinde baskıcı dönemde alınan karar...
# 45  motorsikletin yanından geçen motorcu oluyor am...
# 46  korkum konuyu çarpıtmayada gerek olursa olsun ...
# 47  başkalarına yapılan hukuk dışı ahlak dışı olay...
# 48  doğduğum günden 22 yıl aynı tarihte mezun oldu...
# 49   komiksin burun deliklerini kapat gülerken corona
#
#                                              emojisiz
# 0                           doğa ağzımıza sıçsa hakkı
# 1              anne sanatçıdır güzel eseri yavrusudur
# 2           ibrahimin oğlunu koruyan tanrı’ya sokayım
# 3               köpeğim suratına sıçsın namussuz karı
# 4                          söğüşledim birazda söğüşle
# 5   şerefsizlik sözde sanatçıların vazgeçemediği d...
# 6                        kendisi bilmiyordur beyinsiz
# 7   aşırı bıyıklı geleneksel keko adam ayrılıp bar...
# 8   uzun yolculuklar tek adımla başlar geleceğin m...
# 9                vallahi aralar istediğimiz tek huzur
# 10  chp genel başkanı kemal kılıçdaroğlunun eşi se...
# 11  beyin göçünü engellemeye çalıştığımız gençlere...
# 12               doğa kullanılmayan depoyu devralıyor
# 13  tarlasını çekerken çekmedin söylenenen dayının...
# 14  babaannesini seven yoktur heralde anneanneler ...
# 15  merhaba konuyla ilgili yardımcı olmak isteriz ...
# 16  nietzsche buyurdu zerdüşt’te inşa etmelisin di...
# 17              harekete geçen cehalet korkunç olamaz
# 18     birileri değişimlerin tadını çıkarmakla meşgul
# 19  stanley parable oyun sevebilirsin cümlesini un...
# 20  kitap okuyan insanlarla tanıştıracağım hayat i...
# 21                  yaptığım başarılı aktivite uyumak
# 22  demiş iyilerle kötüler belli diyeit itle gezer...
# 23  faydası olmayan zararı olan saray soytarısı na...
# 24  ulan yanan alevi yakan alevi bugün temel aynı ...
# 25  defol git ölüye saygın anladık bari allahtan k...
# 26  2018den yana formamızı terleten sadece başarıl...
# 27  kanka netflix sayesinde ingilizce ogreniyorum ...
# 28                                            öldürür
# 29  para vermeyeceksin kardeşim para verdin izleme...
# 30                                gay düsmani mustafa
# 31  i̇zlemek istemeyen abone olmaz açık sahneyse e...
# 32                                     izleme dalyrak
# 33  türk televizyon dizileri tecavüz kadına şiddet...
# 34                       i̇zleme amına kodumun koyunu
# 35                      fiyatı fazla geldi gerizekalı
# 36  ezik orospu evladi izleyen ister ucretli uygulama
# 37  i̇zleme ozaman yarram karı görsen düz yokuşa t...
# 38  zehirin aktığı beyniniz ağzınız farkında değil...
# 39  hayatında para vermeden seks yapmamış çevresi ...
# 40  aq ayık gezmezler bulduğunu skerler abazalıkta...
# 41  sus yavşak izleme götüm fakirlerin netfilixi o...
# 42                                  satın almayın amk
# 43               dur dinle ademoğlu geldin gidiyorsun
# 44  hepsinin ötesinde baskıcı dönemde alınan karar...
# 45  motorsikletin yanından geçen motorcu oluyor am...
# 46  korkum konuyu çarpıtmayada gerek olursa olsun ...
# 47  başkalarına yapılan hukuk dışı ahlak dışı olay...
# 48  doğduğum günden 22 yıl aynı tarihte mezun oldu...
# 49   komiksin burun deliklerini kapat gülerken corona

# %%
# Veri seti üzerinde gerçekleşen değişimleri gözlemleyebilmek için her bir işlemi farklı feature'ler oluşturarak yapmıştık.
# Şimdi ise işimize yaramayacak olan feature'leri siliyoruz 
df.drop(["Paylaşım","ozel_karaktersiz","stop_word","sık_kullanılan","kelime_kok"],axis=1,inplace=True)
df.head()
# Out:
#        Tip  sınıf                                   emojisiz
# 0  Negatif      0                  doğa ağzımıza sıçsa hakkı
# 1  Pozitif      1     anne sanatçıdır güzel eseri yavrusudur
# 2  Negatif      0  ibrahimin oğlunu koruyan tanrı’ya sokayım
# 3  Negatif      0      köpeğim suratına sıçsın namussuz karı
# 4  Negatif      0                 söğüşledim birazda söğüşle

# %% [markdown]
# <a id= "3"> </a><br>
# ## Veri Setinin Görselleştirilmesi

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (9,9))
sorted_counts = df['sınıf'].value_counts()
plt.pie(sorted_counts, labels = sorted_counts.index, startangle = 90, counterclock = False, wedgeprops = {'width' : 0.6},
       autopct='%1.1f%%', pctdistance = 0.7, textprops = {'color': 'black', 'fontsize' : 15}, shadow = True,
        colors = sns.color_palette("Paired")[7:])
plt.text(x = -0.35, y = 0, s = 'Toplam Paylaşım: {}'.format(df.shape[0]))
plt.title('Veri Setindeki Paylaşımların Dağılımları', fontsize = 16);

# %%
sns.barplot(x=[1,0],y = df["sınıf"].value_counts())

# %%
df["karakter_len"]= df["emojisiz"].apply(len)
plt.figure("0-1 histogram grafiği")

sns.distplot(df[df["sınıf"]==0]["karakter_len"].values,bins=20 , label = " Negatif değerlerinin histogram")

sns.distplot(df[df["sınıf"]==1]["karakter_len"].values,bins = 20 ,label="Pozitif değerlerin Histogram")

plt.xlabel("Karakter Uzunluğu")
plt.ylabel("Frekans(Yoğunluk)")
plt.legend(loc="best")
plt.show()

# %%
df["kelime"] = df["emojisiz"].apply(lambda x : len(x.split()))

plt.figure("kelimelerin 0 ve 1 değerlerine göre kda sı")

sns.distplot(df[df["sınıf"]==0]["kelime"].values,bins=20,label=" 0 değeri için hist")
sns.distplot(df[df["sınıf"]==1]["kelime"].values,bins=20,label="1 değeri için hist")

plt.xlabel("Kelimee Uzunlukları")
plt.ylabel("Frekans (yoğunluk)")
plt.legend(loc="best")
plt.show()

# %%
from wordcloud import WordCloud

# %%
metin = df.emojisiz.tolist()
metin_kombin = " ".join(metin)
plt.figure(figsize=(14,14))
plt.imshow(WordCloud().generate(metin_kombin))
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
# pozitif sınıflandırıcının görselleştirilmesi

pozitif = df.emojisiz[df.sınıf == 1]

pozitif_metin = pozitif.tolist()
pozitif_metin_ekleme = " ".join(pozitif_metin)
plt.figure(figsize=(14,14))
plt.imshow(WordCloud().generate(pozitif_metin_ekleme))
plt.axis("off")
plt.title("Pozitif Metin")
# Out:
# Text(0.5, 1.0, 'Pozitif Metin')

# %%
# Negatif Metin içindeki en çok kullanılan kelimeler

negatif = df.emojisiz[df.sınıf==0]
negatif_metin= negatif.tolist()
negatif_metin_ekle = " ".join(negatif_metin)
plt.figure(figsize=(14,14))
plt.imshow(WordCloud().generate(negatif_metin_ekle))
plt.axis("off")
plt.title("Negatif Metnin Dağılımı")
# Out:
# Text(0.5, 1.0, 'Negatif Metnin Dağılımı')

# %% [markdown]
# <a id= "4"> </a><br>
# ## Modelin Test ve Eğitim Kümelerine Ayrılması

# %%
train_size = int(len(df)*0.8)
test_size = int(len(df)-train_size)

print("Eğitim Boyuyu=" ,train_size)
print("Test Boyuyu=" ,test_size)
# Out:
# Eğitim Boyuyu= 8888
# Test Boyuyu= 2223

# %%
def df_split (df,train_size):
    train = df[:train_size]
    test= df[train_size:]
    return train,test
train_y,test_y = df_split(df["sınıf"],train_size)
train_x,test_x = df_split(df["emojisiz"],train_size)

# %% [markdown]
# <a id= "5"> </a><br>
# # Sınıflandırma Algoritmalarının Denenmesi

# %%
from sklearn.svm import SVC

# %%
import warnings
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import joblib
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.metrics import accuracy_score, recall_score, f1_score
from sklearn.model_selection import KFold
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier , VotingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
def k_fold (vectorizer, model, data, name):
   
    pipeline = Pipeline([('vect', vectorizer),
                         ('chi', SelectKBest(chi2, k="all")),
                         ('clf', model)])
    kf = KFold(n_splits=15, shuffle=True)
    scores = []
    
    for train_index, test_index in kf.split(df):
        train_text = df.iloc[train_index]['emojisiz'].values.astype('U')
        train_y = df.iloc[train_index]['sınıf'].values.astype('U')

        test_text = df.iloc[test_index]['emojisiz'].values.astype('U')
        test_y = df.iloc[test_index]['sınıf'].values.astype('U')

        model = pipeline.fit(train_text, train_y)
        predictions = model.predict(test_text)
        with warnings.catch_warnings():
            warnings.filterwarnings(action='once')
            score = accuracy_score(test_y, predictions)
            print(score)
            scores.append(score)
            skor=str(sum(scores)/len(scores))
            
    
        return skor

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier, BaggingClassifier

# %%
cv_result=[]
stop_words = set(stopwords.words('turkish'))
vectorizer = TfidfVectorizer(min_df=10, max_df=0.95, sublinear_tf=True, norm='l2',ngram_range=(1, 3), encoding='windows-1254', stop_words=stop_words, analyzer='word')
models = [('LogisticRegression', LogisticRegression(solver='newton-cg', multi_class='multinomial')),
          ('SVC', SVC(kernel = "rbf")),
          ('SGDClassifier', SGDClassifier(tol=1e-3, penalty='l2')),
          ("MultinomialNB",MultinomialNB()),
          ("KNeighborsClassifier",KNeighborsClassifier()),
          ("RandomForestClassifier",RandomForestClassifier (random_state=16)),
          ("DecisionTreeClassifier",DecisionTreeClassifier(random_state=16)),
          ("AdaBoostClassifier",AdaBoostClassifier()),
          ("Bagging Classifier",BaggingClassifier())
         ]
sonuc = {}
for name, model in models:
        
        sonuc.update({name : k_fold(vectorizer, model, df, name)}) 
        print("***************************** \n",sonuc)
# Out:
# 0.8582995951417004
# *****************************
#  {'LogisticRegression': '0.8582995951417004'}
# 0.8259109311740891
# *****************************
#  {'LogisticRegression': '0.8582995951417004', 'SVC': '0.8259109311740891'}
# 0.8663967611336032
# *****************************
#  {'LogisticRegression': '0.8582995951417004', 'SVC': '0.8259109311740891', 'SGDClassifier': '0.8663967611336032'}
# 0.8596491228070176
# *****************************
#  {'LogisticRegression': '0.8582995951417004', 'SVC': '0.8259109311740891', 'SGDClassifier': '0.8663967611336032', 'MultinomialNB': '0.8596491228070176'}
# 0.7462887989203779
# *****************************
#  {'LogisticRegression': '0.8582995951417004', 'SVC': '0.8259109311740891', 'SGDClassifier': '0.8663967611336032', 'MultinomialNB': '0.8596491228070176', 'KNeighborsClassifier': '0.7462887989203779'}
# 0.8556005398110661
# *****************************
#  {'LogisticRegression': '0.8582995951417004', 'SVC': '0.8259109311740891', 'SGDClassifier': '0.8663967611336032', 'MultinomialNB': '0.8596491228070176', 'KNeighborsClassifier': '0.7462887989203779', 'RandomForestClassifier': '0.8556005398110661'}
# 0.8043184885290149
# *****************************
#  {'LogisticRegression': '0.8582995951417004', 'SVC': '0.8259109311740891', 'SGDClassifier': '0.8663967611336032', 'MultinomialNB': '0.8596491228070176', 'KNeighborsClassifier': '0.7462887989203779', 'RandomForestClassifier': '0.8556005398110661', 'DecisionTreeClassifier': '0.8043184885290149'}
# 0.786774628879892
# *****************************
#  {'LogisticRegression': '0.8582995951417004', 'SVC': '0.8259109311740891', 'SGDClassifier': '0.8663967611336032', 'MultinomialNB': '0.8596491228070176', 'KNeighborsClassifier': '0.7462887989203779', 'RandomForestClassifier': '0.8556005398110661', 'DecisionTreeClassifier': '0.8043184885290149', 'AdaBoostClassifier': '0.786774628879892'}
# 0.8502024291497976
# *****************************
#  {'LogisticRegression': '0.8582995951417004', 'SVC': '0.8259109311740891', 'SGDClassifier': '0.8663967611336032', 'MultinomialNB': '0.8596491228070176', 'KNeighborsClassifier': '0.7462887989203779', 'RandomForestClassifier': '0.8556005398110661', 'DecisionTreeClassifier': '0.8043184885290149', 'AdaBoostClassifier': '0.786774628879892', 'Bagging Classifier': '0.8502024291497976'}

# %%
# Denediğimi algoritmaları bir sonuc adlı Dictionary değişkenine kaydetmiştik. 
# Burada ise bu sözlüğü bir data frame dönüşütürüyoruz
sozluk = list(sonuc.items())
array_dic = np.array(sozluk)
print("Dizi Şekli*** \n",array_dic,"\n")
visualDF = pd.DataFrame ( data = array_dic ,columns= ["Model Adı","Başarım Oranı"])
visualDF.head(9)
# Out:
# Dizi Şekli***
#  [['LogisticRegression' '0.8582995951417004']
#  ['SVC' '0.8259109311740891']
#  ['SGDClassifier' '0.8663967611336032']
#  ['MultinomialNB' '0.8596491228070176']
#  ['KNeighborsClassifier' '0.7462887989203779']
#  ['RandomForestClassifier' '0.8556005398110661']
#  ['DecisionTreeClassifier' '0.8043184885290149']
#  ['AdaBoostClassifier' '0.786774628879892']
#  ['Bagging Classifier' '0.8502024291497976']]
#                 Model Adı       Başarım Oranı
# 0      LogisticRegression  0.8582995951417004
# 1                     SVC  0.8259109311740891
# 2           SGDClassifier  0.8663967611336032
# 3           MultinomialNB  0.8596491228070176
# 4    KNeighborsClassifier  0.7462887989203779
# 5  RandomForestClassifier  0.8556005398110661
# 6  DecisionTreeClassifier  0.8043184885290149
# 7      AdaBoostClassifier   0.786774628879892
# 8      Bagging Classifier  0.8502024291497976

# %% [markdown]
# <a id= "6"> </a><br>
# # Sonuç

# %% [markdown]
# 9 farklı makine öğrenmesi algortiması kullanılarak sınıflandırma işlemi gerçekleştirilmiş ve başarım oranı en yüksek algoritma şekilde verilmiştir.

# %%
g = sns.barplot("Başarım Oranı","Model Adı",data=visualDF)
g.set_xlabel("Mean Accuracy")
g.set_title("Cross Validation Scores")
# Out:
# Text(0.5, 1.0, 'Cross Validation Scores')

# %%
def basarım (sonuc):
    max_basarım = max(sonuc,key = sonuc.get)
    return (max_basarım)
print("Yapmış olduğumuz 9 farklı makine öğrenmesi algoritması arasında en başarılı sonucu veren algoritma = {} ' dir".format(basarım(sonuc)))
# Out:
# Yapmış olduğumuz 9 farklı makine öğrenmesi algoritması arasında en başarılı sonucu veren algoritma = SGDClassifier ' dir
